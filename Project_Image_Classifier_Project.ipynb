# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# The new version of dataset is only available in the tfds-nightly package.
# %pip --no-cache-dir install tfds-nightly --user
# DON'T MISS TO RESTART THE KERNEL
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Can not perform a '--user' install. User site-packages are not visible in this virtualenv.

# %%
# Import TensorFlow 
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_hub as hub

# %%
# TODO: Make all other necessary imports.
import numpy as np
import matplotlib.pyplot as plt
import logging
import json
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# Download data to default local directory "~/tensorflow_datasets"
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102

# TODO: Load the dataset with TensorFlow Datasets. Hint: use tfds.load()
dataset, dataset_info = tfds.load('oxford_flowers102', as_supervised = True, \
                                  with_info = True, data_dir = '~/tensorflow_datasets')

# TODO: Create a training set, a validation set and a test set.
training_set, validation_set, test_set = dataset['train'], dataset['validation'], dataset['test']

num_train, num_test, num_validate = (dataset_info.splits['train'].num_examples, 
                                     dataset_info.splits['test'].num_examples, 
                                     dataset_info.splits['validation'].num_examples)

IMG_SIZE = 224
# Out:
# 2020-08-29 20:16:02.254749: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-08-29 20:16:02.254929: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# I0829 20:16:04.657160 14052 download_and_prepare.py:201] Running download_and_prepare for dataset(s):
# oxford_flowers102
# I0829 20:16:04.658149 14052 download_and_prepare.py:139] download_and_prepare for dataset oxford_flowers102/2.1.1...
# I0829 20:16:04.659124 14052 dataset_builder.py:346] Generating dataset oxford_flowers102 (C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1)
#
# Dl Completed...: 0 url [00:00, ? url/s]
#
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:00, ? file/s]I0829 20:16:04.770331 14052 download_manager.py:477] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz into C:\Users\alexa\tensorflow_datasets\downloads\robots.ox.ac.uk_vgg_flowers_102_102flowersoWedSp98maBn1wypsDib6T-q2NVbO40fwvTflmPmQpY.tgz.tmp.f4ca48a649af46bc903d6b8d5428b00b...
#
# Dl Completed...:   0%|          | 0/1 [00:00<?, ? url/s]
#
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:00, ? file/s]I0829 20:16:04.774316 14052 download_manager.py:477] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat into C:\Users\alexa\tensorflow_datasets\downloads\robots.ox.ac.uk_vgg_flowers_102_imagelabelQc558tX8AD-RkJuVyV4EyAI3B3yv3pQFw82vzoHJBkI.mat.tmp.54b8485da9314de3a5388f2589c05246...
#
# Dl Completed...:   0%|          | 0/2 [00:00<?, ? url/s]
#
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:00, ? file/s]I0829 20:16:04.777275 14052 download_manager.py:477] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat into C:\Users\alexa\tensorflow_datasets\downloads\robots.ox.ac.uk_vgg_flowers_102_setidSMkjURnWabtzYOtl4t1kAcvHb6vlLbDJOlQsTHUux60.mat.tmp.1473ddabb0b443b08af1b40d89f52853...
#
# Dl Completed...:   0%|          | 0/3 [00:00<?, ? url/s]
#
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|          | 0/3 [00:02<?, ? url/s]
#
# Dl Size...:   0%|          | 0/328 [00:02<?, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|          | 0/3 [00:02<?, ? url/s]
#
# Dl Size...:   0%|          | 0/328 [00:02<?, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:  33%|###3      | 1/3 [00:02<00:04,  2.07s/ url]
# Dl Completed...:  33%|###3      | 1/3 [00:02<00:04,  2.07s/ url]
#
# Dl Size...:   0%|          | 0/328 [00:02<?, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:02, ? file/s]I0829 20:16:06.841696 23612 download_manager.py:496] Skipping extraction for C:\Users\alexa\tensorflow_datasets\downloads\robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat (method=NO_EXTRACT).
#
# Dl Completed...:  33%|###3      | 1/3 [00:02<00:04,  2.07s/ url]
#
# Dl Size...:   0%|          | 0/328 [00:02<?, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:  67%|######6   | 2/3 [00:02<00:01,  1.51s/ url]
# Dl Completed...:  67%|######6   | 2/3 [00:02<00:01,  1.51s/ url]
#
# Dl Size...:   0%|          | 0/328 [00:02<?, ? MiB/s]
#
#
# Extraction completed...: 0 file [00:02, ? file/s]I0829 20:16:07.040383 14756 download_manager.py:496] Skipping extraction for C:\Users\alexa\tensorflow_datasets\downloads\robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat (method=NO_EXTRACT).
#
#
# Dl Size...:   0%|          | 1/328 [00:05<27:43,  5.09s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:05<00:01,  1.51s/ url]
#
# Dl Size...:   0%|          | 1/328 [00:05<27:43,  5.09s/ MiB]
#
#
# Extraction completed...: 0 file [00:05, ? file/s]
#
# Dl Size...:   1%|          | 2/328 [00:07<23:49,  4.39s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:07<00:01,  1.51s/ url]
#
# Dl Size...:   1%|          | 2/328 [00:07<23:49,  4.39s/ MiB]
#
#
# Extraction completed...: 0 file [00:07, ? file/s]
#
# Dl Size...:   1%|          | 3/328 [00:10<21:05,  3.89s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:10<00:01,  1.51s/ url]
#
# Dl Size...:   1%|          | 3/328 [00:10<21:05,  3.89s/ MiB]
#
#
# Extraction completed...: 0 file [00:10, ? file/s]
#
# Dl Size...:   1%|1         | 4/328 [00:13<19:19,  3.58s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:13<00:01,  1.51s/ url]
#
# Dl Size...:   1%|1         | 4/328 [00:13<19:19,  3.58s/ MiB]
#
#
# Extraction completed...: 0 file [00:13, ? file/s]
#
# Dl Size...:   2%|1         | 5/328 [00:16<17:54,  3.33s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:16<00:01,  1.51s/ url]
#
# Dl Size...:   2%|1         | 5/328 [00:16<17:54,  3.33s/ MiB]
#
#
# Extraction completed...: 0 file [00:16, ? file/s]
#
# Dl Size...:   2%|1         | 6/328 [00:19<17:09,  3.20s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:19<00:01,  1.51s/ url]
#
# Dl Size...:   2%|1         | 6/328 [00:19<17:09,  3.20s/ MiB]
#
#
# Extraction completed...: 0 file [00:19, ? file/s]
#
# Dl Size...:   2%|2         | 7/328 [00:21<16:20,  3.05s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:21<00:01,  1.51s/ url]
#
# Dl Size...:   2%|2         | 7/328 [00:21<16:20,  3.05s/ MiB]
#
#
# Extraction completed...: 0 file [00:21, ? file/s]
#
# Dl Size...:   2%|2         | 8/328 [00:24<15:58,  2.99s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:24<00:01,  1.51s/ url]
#
# Dl Size...:   2%|2         | 8/328 [00:24<15:58,  2.99s/ MiB]
#
#
# Extraction completed...: 0 file [00:24, ? file/s]
#
# Dl Size...:   3%|2         | 9/328 [00:27<15:33,  2.92s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:27<00:01,  1.51s/ url]
#
# Dl Size...:   3%|2         | 9/328 [00:27<15:33,  2.92s/ MiB]
#
#
# Extraction completed...: 0 file [00:27, ? file/s]
#
# Dl Size...:   3%|3         | 10/328 [00:30<15:11,  2.87s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:30<00:01,  1.51s/ url]
#
# Dl Size...:   3%|3         | 10/328 [00:30<15:11,  2.87s/ MiB]
#
#
# Extraction completed...: 0 file [00:30, ? file/s]
#
# Dl Size...:   3%|3         | 11/328 [00:32<15:08,  2.87s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:32<00:01,  1.51s/ url]
#
# Dl Size...:   3%|3         | 11/328 [00:32<15:08,  2.87s/ MiB]
#
#
# Extraction completed...: 0 file [00:32, ? file/s]
#
# Dl Size...:   4%|3         | 12/328 [00:35<14:51,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:35<00:01,  1.51s/ url]
#
# Dl Size...:   4%|3         | 12/328 [00:35<14:51,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [00:35, ? file/s]
#
# Dl Size...:   4%|3         | 13/328 [00:38<14:54,  2.84s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:38<00:01,  1.51s/ url]
#
# Dl Size...:   4%|3         | 13/328 [00:38<14:54,  2.84s/ MiB]
#
#
# Extraction completed...: 0 file [00:38, ? file/s]
#
# Dl Size...:   4%|4         | 14/328 [00:41<14:40,  2.80s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:41<00:01,  1.51s/ url]
#
# Dl Size...:   4%|4         | 14/328 [00:41<14:40,  2.80s/ MiB]
#
#
# Extraction completed...: 0 file [00:41, ? file/s]
#
# Dl Size...:   5%|4         | 15/328 [00:44<14:31,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:44<00:01,  1.51s/ url]
#
# Dl Size...:   5%|4         | 15/328 [00:44<14:31,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [00:44, ? file/s]
#
# Dl Size...:   5%|4         | 16/328 [00:46<14:38,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:46<00:01,  1.51s/ url]
#
# Dl Size...:   5%|4         | 16/328 [00:46<14:38,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [00:46, ? file/s]
#
# Dl Size...:   5%|5         | 17/328 [00:49<14:28,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:49<00:01,  1.51s/ url]
#
# Dl Size...:   5%|5         | 17/328 [00:49<14:28,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [00:49, ? file/s]
#
# Dl Size...:   5%|5         | 18/328 [00:52<14:37,  2.83s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:52<00:01,  1.51s/ url]
#
# Dl Size...:   5%|5         | 18/328 [00:52<14:37,  2.83s/ MiB]
#
#
# Extraction completed...: 0 file [00:52, ? file/s]
#
# Dl Size...:   6%|5         | 19/328 [00:55<14:27,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:55<00:01,  1.51s/ url]
#
# Dl Size...:   6%|5         | 19/328 [00:55<14:27,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [00:55, ? file/s]
#
# Dl Size...:   6%|6         | 20/328 [00:58<14:29,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [00:58<00:01,  1.51s/ url]
#
# Dl Size...:   6%|6         | 20/328 [00:58<14:29,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [00:58, ? file/s]
#
# Dl Size...:   6%|6         | 21/328 [01:00<14:23,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:00<00:01,  1.51s/ url]
#
# Dl Size...:   6%|6         | 21/328 [01:00<14:23,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [01:00, ? file/s]
#
# Dl Size...:   7%|6         | 22/328 [01:03<14:11,  2.78s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:03<00:01,  1.51s/ url]
#
# Dl Size...:   7%|6         | 22/328 [01:03<14:11,  2.78s/ MiB]
#
#
# Extraction completed...: 0 file [01:03, ? file/s]
#
# Dl Size...:   7%|7         | 23/328 [01:06<14:10,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:06<00:01,  1.51s/ url]
#
# Dl Size...:   7%|7         | 23/328 [01:06<14:10,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [01:06, ? file/s]
#
# Dl Size...:   7%|7         | 24/328 [01:09<14:08,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:09<00:01,  1.51s/ url]
#
# Dl Size...:   7%|7         | 24/328 [01:09<14:08,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [01:09, ? file/s]
#
# Dl Size...:   8%|7         | 25/328 [01:12<14:03,  2.78s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:12<00:01,  1.51s/ url]
#
# Dl Size...:   8%|7         | 25/328 [01:12<14:03,  2.78s/ MiB]
#
#
# Extraction completed...: 0 file [01:12, ? file/s]
#
# Dl Size...:   8%|7         | 26/328 [01:14<14:09,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:14<00:01,  1.51s/ url]
#
# Dl Size...:   8%|7         | 26/328 [01:14<14:09,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [01:14, ? file/s]
#
# Dl Size...:   8%|8         | 27/328 [01:17<14:00,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:17<00:01,  1.51s/ url]
#
# Dl Size...:   8%|8         | 27/328 [01:17<14:00,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [01:17, ? file/s]
#
# Dl Size...:   9%|8         | 28/328 [01:20<14:07,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:20<00:01,  1.51s/ url]
#
# Dl Size...:   9%|8         | 28/328 [01:20<14:07,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [01:20, ? file/s]
#
# Dl Size...:   9%|8         | 29/328 [01:23<13:57,  2.80s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01:23<00:01,  1.51s/ url]
#
# Dl Size...:   9%|8         | 29/328 [01:23<13:57,  2.80s/ MiB]
#
#
# Extraction completed...: 0 file [01:23, ? file/s]
#
# Dl Size...:   9%|9         | 30/328 [01:26<14:03,  2.83s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [01
  2.77s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:40<00:01,  1.51s/ url]
#
# Dl Size...:  24%|##3       | 78/328 [03:40<11:33,  2.77s/ MiB]
#
#
# Extraction completed...: 0 file [03:40, ? file/s]
#
# Dl Size...:  24%|##4       | 79/328 [03:43<11:30,  2.77s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:43<00:01,  1.51s/ url]
#
# Dl Size...:  24%|##4       | 79/328 [03:43<11:30,  2.77s/ MiB]
#
#
# Extraction completed...: 0 file [03:43, ? file/s]
#
# Dl Size...:  24%|##4       | 80/328 [03:45<11:20,  2.75s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:45<00:01,  1.51s/ url]
#
# Dl Size...:  24%|##4       | 80/328 [03:45<11:20,  2.75s/ MiB]
#
#
# Extraction completed...: 0 file [03:45, ? file/s]
#
# Dl Size...:  25%|##4       | 81/328 [03:48<11:19,  2.75s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:48<00:01,  1.51s/ url]
#
# Dl Size...:  25%|##4       | 81/328 [03:48<11:19,  2.75s/ MiB]
#
#
# Extraction completed...: 0 file [03:48, ? file/s]
#
# Dl Size...:  25%|##5       | 82/328 [03:51<11:15,  2.75s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:51<00:01,  1.51s/ url]
#
# Dl Size...:  25%|##5       | 82/328 [03:51<11:15,  2.75s/ MiB]
#
#
# Extraction completed...: 0 file [03:51, ? file/s]
#
# Dl Size...:  25%|##5       | 83/328 [03:53<11:09,  2.73s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:53<00:01,  1.51s/ url]
#
# Dl Size...:  25%|##5       | 83/328 [03:53<11:09,  2.73s/ MiB]
#
#
# Extraction completed...: 0 file [03:53, ? file/s]
#
# Dl Size...:  26%|##5       | 84/328 [03:56<11:12,  2.75s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:56<00:01,  1.51s/ url]
#
# Dl Size...:  26%|##5       | 84/328 [03:56<11:12,  2.75s/ MiB]
#
#
# Extraction completed...: 0 file [03:56, ? file/s]
#
# Dl Size...:  26%|##5       | 85/328 [03:59<11:04,  2.73s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [03:59<00:01,  1.51s/ url]
#
# Dl Size...:  26%|##5       | 85/328 [03:59<11:04,  2.73s/ MiB]
#
#
# Extraction completed...: 0 file [03:59, ? file/s]
#
# Dl Size...:  26%|##6       | 86/328 [04:02<11:06,  2.76s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04:02<00:01,  1.51s/ url]
#
# Dl Size...:  26%|##6       | 86/328 [04:02<11:06,  2.76s/ MiB]
#
#
# Extraction completed...: 0 file [04:02, ? file/s]
#
# Dl Size...:  27%|##6       | 87/328 [04:04<11:05,  2.76s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04:04<00:01,  1.51s/ url]
#
# Dl Size...:  27%|##6       | 87/328 [04:04<11:05,  2.76s/ MiB]
#
#
# Extraction completed...: 0 file [04:04, ? file/s]
#
# Dl Size...:  27%|##6       | 88/328 [04:07<10:59,  2.75s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04:07<00:01,  1.51s/ url]
#
# Dl Size...:  27%|##6       | 88/328 [04:07<10:59,  2.75s/ MiB]
#
#
# Extraction completed...: 0 file [04:07, ? file/s]
#
# Dl Size...:  27%|##7       | 89/328 [04:10<10:59,  2.76s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04:10<00:01,  1.51s/ url]
#
# Dl Size...:  27%|##7       | 89/328 [04:10<10:59,  2.76s/ MiB]
#
#
# Extraction completed...: 0 file [04:10, ? file/s]
#
# Dl Size...:  27%|##7       | 90/328 [04:13<10:59,  2.77s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04:13<00:01,  1.51s/ url]
#
# Dl Size...:  27%|##7       | 90/328 [04:13<10:59,  2.77s/ MiB]
#
#
# Extraction completed...: 0 file [04:13, ? file/s]
#
# Dl Size...:  28%|##7       | 91/328 [04:16<10:54,  2.76s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [04
/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:00<00:01,  1.51s/ url]
#
# Dl Size...:  32%|###2      | 106/328 [05:00<11:42,  3.17s/ MiB]
#
#
# Extraction completed...: 0 file [05:00, ? file/s]
#
# Dl Size...:  33%|###2      | 107/328 [05:03<11:13,  3.05s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:03<00:01,  1.51s/ url]
#
# Dl Size...:  33%|###2      | 107/328 [05:03<11:13,  3.05s/ MiB]
#
#
# Extraction completed...: 0 file [05:03, ? file/s]
#
# Dl Size...:  33%|###2      | 108/328 [05:06<10:59,  3.00s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:06<00:01,  1.51s/ url]
#
# Dl Size...:  33%|###2      | 108/328 [05:06<10:59,  3.00s/ MiB]
#
#
# Extraction completed...: 0 file [05:06, ? file/s]
#
# Dl Size...:  33%|###3      | 109/328 [05:09<10:42,  2.94s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:09<00:01,  1.51s/ url]
#
# Dl Size...:  33%|###3      | 109/328 [05:09<10:42,  2.94s/ MiB]
#
#
# Extraction completed...: 0 file [05:09, ? file/s]
#
# Dl Size...:  34%|###3      | 110/328 [05:15<14:20,  3.95s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:15<00:01,  1.51s/ url]
#
# Dl Size...:  34%|###3      | 110/328 [05:15<14:20,  3.95s/ MiB]
#
#
# Extraction completed...: 0 file [05:15, ? file/s]
#
# Dl Size...:  34%|###3      | 111/328 [05:18<13:17,  3.67s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:18<00:01,  1.51s/ url]
#
# Dl Size...:  34%|###3      | 111/328 [05:18<13:17,  3.67s/ MiB]
#
#
# Extraction completed...: 0 file [05:18, ? file/s]
#
# Dl Size...:  34%|###4      | 112/328 [05:21<12:13,  3.40s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:21<00:01,  1.51s/ url]
#
# Dl Size...:  34%|###4      | 112/328 [05:21<12:13,  3.40s/ MiB]
#
#
# Extraction completed...: 0 file [05:21, ? file/s]
#
# Dl Size...:  34%|###4      | 113/328 [05:24<11:30,  3.21s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:24<00:01,  1.51s/ url]
#
# Dl Size...:  34%|###4      | 113/328 [05:24<11:30,  3.21s/ MiB]
#
#
# Extraction completed...: 0 file [05:24, ? file/s]
#
# Dl Size...:  35%|###4      | 114/328 [05:26<11:01,  3.09s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:26<00:01,  1.51s/ url]
#
# Dl Size...:  35%|###4      | 114/328 [05:26<11:01,  3.09s/ MiB]
#
#
# Extraction completed...: 0 file [05:26, ? file/s]
#
# Dl Size...:  35%|###5      | 115/328 [05:29<10:37,  2.99s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:29<00:01,  1.51s/ url]
#
# Dl Size...:  35%|###5      | 115/328 [05:29<10:37,  2.99s/ MiB]
#
#
# Extraction completed...: 0 file [05:29, ? file/s]
#
# Dl Size...:  35%|###5      | 116/328 [05:32<10:25,  2.95s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:32<00:01,  1.51s/ url]
#
# Dl Size...:  35%|###5      | 116/328 [05:32<10:25,  2.95s/ MiB]
#
#
# Extraction completed...: 0 file [05:32, ? file/s]
#
# Dl Size...:  36%|###5      | 117/328 [05:35<10:08,  2.88s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:35<00:01,  1.51s/ url]
# Downloading and preparing dataset oxford_flowers102/2.1.1 (download: Unknown size, generated: Unknown size, total: Unknown size) to C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1...
#
#
#
# Shuffling and writing examples to C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-train.tfrecord
# Shuffling and writing examples to C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-test.tfrecord
# Shuffling and writing examples to C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-validation.tfrecord
# Dataset oxford_flowers102 downloaded and prepared to C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1. Subsequent calls will reuse this data.
# name: "oxford_flowers102"
# description: "The Oxford Flowers 102 dataset is a consistent of 102 flower categories commonly occurring\nin the United Kingdom. Each class consists of between 40 and 258 images. The images have\nlarge scale, pose and light variations. In addition, there are categories that have large\nvariations within the category and several very similar categories.\n\nThe dataset is divided into a training set, a validation set and a test set.\nThe training set and validation set each consist of 10 images per class (totalling 1020 images each).\nThe test set consists of the remaining 6149 images (minimum 20 per class)."
# citation: "@InProceedings{Nilsback08,\n   author = \"Nilsback, M-E. and Zisserman, A.\",\n   title = \"Automated Flower Classification over a Large Number of Classes\",\n   booktitle = \"Proceedings of the Indian Conference on Computer Vision, Graphics and Image Processing\",\n   year = \"2008\",\n   month = \"Dec\"\n}"
# location {
#   urls: "https://www.robots.ox.ac.uk/~vgg/data/flowers/102/"
# }
# splits {
#   name: "test"
#   shard_lengths: 3074
#   shard_lengths: 3075
#   num_bytes: 260784877
# }
# splits {
#   name: "train"
#   shard_lengths: 1020
#   num_bytes: 43474584
# }
# splits {
#   name: "validation"
#   shard_lengths: 1020
#   num_bytes: 43180278
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "2.1.1"
# download_size: 344878000
# Dl Size...:  36%|###5      | 117/328 [05:35<10:08,  2.88s/ MiB]
#
#
# Extraction completed...: 0 file [05:35, ? file/s]
#
# Dl Size...:  36%|###5      | 118/328 [05:38<10:02,  2.87s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:38<00:01,  1.51s/ url]
#
# Dl Size...:  36%|###5      | 118/328 [05:38<10:02,  2.87s/ MiB]
#
#
# Extraction completed...: 0 file [05:38, ? file/s]
#
# Dl Size...:  36%|###6      | 119/328 [05:40<09:52,  2.84s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:40<00:01,  1.51s/ url]
#
# Dl Size...:  36%|###6      | 119/328 [05:40<09:52,  2.84s/ MiB]
#
#
# Extraction completed...: 0 file [05:40, ? file/s]
#
# Dl Size...:  37%|###6      | 120/328 [05:43<09:43,  2.80s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:43<00:01,  1.51s/ url]
#
# Dl Size...:  37%|###6      | 120/328 [05:43<09:43,  2.80s/ MiB]
#
#
# Extraction completed...: 0 file [05:43, ? file/s]
#
# Dl Size...:  37%|###6      | 121/328 [05:46<09:49,  2.85s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:46<00:01,  1.51s/ url]
#
# Dl Size...:  37%|###6      | 121/328 [05:46<09:49,  2.85s/ MiB]
#
#
# Extraction completed...: 0 file [05:46, ? file/s]
#
# Dl Size...:  37%|###7      | 122/328 [05:49<09:39,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:49<00:01,  1.51s/ url]
#
# Dl Size...:  37%|###7      | 122/328 [05:49<09:39,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [05:49, ? file/s]
#
# Dl Size...:  38%|###7      | 123/328 [05:52<09:38,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:52<00:01,  1.51s/ url]
#
# Dl Size...:  38%|###7      | 123/328 [05:52<09:38,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [05:52, ? file/s]
#
# Dl Size...:  38%|###7      | 124/328 [05:55<09:35,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:55<00:01,  1.51s/ url]
#
# Dl Size...:  38%|###7      | 124/328 [05:55<09:35,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [05:55, ? file/s]
#
# Dl Size...:  38%|###8      | 125/328 [05:57<09:30,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [05:57<00:01,  1.51s/ url]
#
# Dl Size...:  38%|###8      | 125/328 [05:57<09:30,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [05:57, ? file/s]
#
# Dl Size...:  38%|###8      | 126/328 [06:00<09:30,  2.83s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06
/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:43<00:01,  1.51s/ url]
#
# Dl Size...:  43%|####2     | 141/328 [06:43<09:27,  3.03s/ MiB]
#
#
# Extraction completed...: 0 file [06:43, ? file/s]
#
# Dl Size...:  43%|####3     | 142/328 [06:46<09:07,  2.94s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:46<00:01,  1.51s/ url]
#
# Dl Size...:  43%|####3     | 142/328 [06:46<09:07,  2.94s/ MiB]
#
#
# Extraction completed...: 0 file [06:46, ? file/s]
#
# Dl Size...:  44%|####3     | 143/328 [06:49<09:07,  2.96s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:49<00:01,  1.51s/ url]
#
# Dl Size...:  44%|####3     | 143/328 [06:49<09:07,  2.96s/ MiB]
#
#
# Extraction completed...: 0 file [06:49, ? file/s]
#
# Dl Size...:  44%|####3     | 144/328 [06:52<09:08,  2.98s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:52<00:01,  1.51s/ url]
#
# Dl Size...:  44%|####3     | 144/328 [06:52<09:08,  2.98s/ MiB]
#
#
# Extraction completed...: 0 file [06:52, ? file/s]
#
# Dl Size...:  44%|####4     | 145/328 [06:55<09:09,  3.00s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:55<00:01,  1.51s/ url]
#
# Dl Size...:  44%|####4     | 145/328 [06:55<09:09,  3.00s/ MiB]
#
#
# Extraction completed...: 0 file [06:55, ? file/s]
#
# Dl Size...:  45%|####4     | 146/328 [06:58<09:16,  3.06s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [06:58<00:01,  1.51s/ url]
#
# Dl Size...:  45%|####4     | 146/328 [06:58<09:16,  3.06s/ MiB]
#
#
# Extraction completed...: 0 file [06:58, ? file/s]
#
# Dl Size...:  45%|####4     | 147/328 [07:02<09:46,  3.24s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:02<00:01,  1.51s/ url]
#
# Dl Size...:  45%|####4     | 147/328 [07:02<09:46,  3.24s/ MiB]
#
#
# Extraction completed...: 0 file [07:02, ? file/s]
#
# Dl Size...:  45%|####5     | 148/328 [07:05<09:16,  3.09s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:05<00:01,  1.51s/ url]
#
# Dl Size...:  45%|####5     | 148/328 [07:05<09:16,  3.09s/ MiB]
#
#
# Extraction completed...: 0 file [07:05, ? file/s]
#
# Dl Size...:  45%|####5     | 149/328 [07:07<08:54,  2.98s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:07<00:01,  1.51s/ url]
#
# Dl Size...:  45%|####5     | 149/328 [07:07<08:54,  2.98s/ MiB]
#
#
# Extraction completed...: 0 file [07:07, ? file/s]
#
# Dl Size...:  46%|####5     | 150/328 [07:10<08:42,  2.94s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:10<00:01,  1.51s/ url]
#
# Dl Size...:  46%|####5     | 150/328 [07:10<08:42,  2.94s/ MiB]
#
#
# Extraction completed...: 0 file [07:10, ? file/s]
#
# Dl Size...:  46%|####6     | 151/328 [07:13<08:35,  2.91s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:13<00:01,  1.51s/ url]
#
# Dl Size...:  46%|####6     | 151/328 [07:13<08:35,  2.91s/ MiB]
#
#
# Extraction completed...: 0 file [07:13, ? file/s]
#
# Dl Size...:  46%|####6     | 152/328 [07:16<08:27,  2.88s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07:16<00:01,  1.51s/ url]
#
# Dl Size...:  46%|####6     | 152/328 [07:16<08:27,  2.88s/ MiB]
#
#
# Extraction completed...: 0 file [07:16, ? file/s]
#
# Dl Size...:  47%|####6     | 153/328 [07:19<08:20,  2.86s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [07
  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:07<00:01,  1.51s/ url]
#
# Dl Size...:  91%|#########1| 299/328 [14:07<01:21,  2.81s/ MiB]
#
#
# Extraction completed...: 0 file [14:07, ? file/s]
#
# Dl Size...:  91%|#########1| 300/328 [14:10<01:18,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:10<00:01,  1.51s/ url]
#
# Dl Size...:  91%|#########1| 300/328 [14:10<01:18,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [14:10, ? file/s]
#
# Dl Size...:  92%|#########1| 301/328 [14:15<01:36,  3.57s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:15<00:01,  1.51s/ url]
#
# Dl Size...:  92%|#########1| 301/328 [14:15<01:36,  3.57s/ MiB]
#
#
# Extraction completed...: 0 file [14:15, ? file/s]
#
# Dl Size...:  92%|#########2| 302/328 [14:18<01:27,  3.36s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:18<00:01,  1.51s/ url]
#
# Dl Size...:  92%|#########2| 302/328 [14:18<01:27,  3.36s/ MiB]
#
#
# Extraction completed...: 0 file [14:18, ? file/s]
#
# Dl Size...:  92%|#########2| 303/328 [14:21<01:19,  3.18s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:21<00:01,  1.51s/ url]
#
# Dl Size...:  92%|#########2| 303/328 [14:21<01:19,  3.18s/ MiB]
#
#
# Extraction completed...: 0 file [14:21, ? file/s]
#
# Dl Size...:  93%|#########2| 304/328 [14:24<01:14,  3.08s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:24<00:01,  1.51s/ url]
#
# Dl Size...:  93%|#########2| 304/328 [14:24<01:14,  3.08s/ MiB]
# Extraction completed...: 0 file [14:24, ? file/s]
#
# Dl Size...:  93%|#########2| 305/328 [14:27<01:08,  2.97s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:27<00:01,  1.51s/ url]
#
# Dl Size...:  93%|#########2| 305/328 [14:27<01:08,  2.97s/ MiB]
#
#
# Extraction completed...: 0 file [14:27, ? file/s]
#
# Dl Size...:  93%|#########3| 306/328 [14:29<01:04,  2.92s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:29<00:01,  1.51s/ url]
#
# Dl Size...:  93%|#########3| 306/328 [14:29<01:04,  2.92s/ MiB]
#
#
# Extraction completed...: 0 file [14:29, ? file/s]
#
# Dl Size...:  94%|#########3| 307/328 [14:32<01:00,  2.89s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:32<00:01,  1.51s/ url]
#
# Dl Size...:  94%|#########3| 307/328 [14:32<01:00,  2.89s/ MiB]
#
#
# Extraction completed...: 0 file [14:32, ? file/s]
#
# Dl Size...:  94%|#########3| 308/328 [14:35<00:57,  2.85s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:35<00:01,  1.51s/ url]
#
# Dl Size...:  94%|#########3| 308/328 [14:35<00:57,  2.85s/ MiB]
#
#
# Extraction completed...: 0 file [14:35, ? file/s]
#
# Dl Size...:  94%|#########4| 309/328 [14:38<00:54,  2.86s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:38<00:01,  1.51s/ url]
#
# Dl Size...:  94%|#########4| 309/328 [14:38<00:54,  2.86s/ MiB]
#
#
# Extraction completed...: 0 file [14:38, ? file/s]
#
# Dl Size...:  95%|#########4| 310/328 [14:41<00:50,  2.82s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:41<00:01,  1.51s/ url]
#
# Dl Size...:  95%|#########4| 310/328 [14:41<00:50,  2.82s/ MiB]
#
#
# Extraction completed...: 0 file [14:41, ? file/s]
#
# Dl Size...:  95%|#########4| 311/328 [14:43<00:48,  2.84s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14:43<00:01,  1.51s/ url]
#
# Dl Size...:  95%|#########4| 311/328 [14:43<00:48,  2.84s/ MiB]
#
#
# Extraction completed...: 0 file [14:43, ? file/s]
#
# Dl Size...:  95%|#########5| 312/328 [14:46<00:44,  2.81s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [14
/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [15:28<00:01,  1.51s/ url]
#
# Dl Size...: 100%|#########9| 327/328 [15:28<00:02,  2.77s/ MiB]
#
#
# Extraction completed...: 0 file [15:28, ? file/s]
#
# Dl Size...: 100%|##########| 328/328 [15:31<00:00,  2.79s/ MiB]
# Dl Completed...:  67%|######6   | 2/3 [15:31<00:01,  1.51s/ url]
#
# Dl Size...: 100%|##########| 328/328 [15:31<00:00,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [15:31, ? file/s]
# Dl Completed...: 100%|##########| 3/3 [15:33<00:00, 280.46s/ url]
# Dl Completed...: 100%|##########| 3/3 [15:33<00:00, 280.46s/ url]
#
# Dl Size...: 100%|##########| 328/328 [15:33<00:00,  2.79s/ MiB]
#
#
# Extraction completed...: 0 file [15:33, ? file/s]
# Dl Completed...: 100%|##########| 3/3 [15:33<00:00, 280.46s/ url]
#
# Dl Size...: 100%|##########| 328/328 [15:33<00:00,  2.79s/ MiB]
#
#
# Extraction completed...:   0%|          | 0/1 [15:33<?, ? file/s]
#
#
# Extraction completed...: 100%|##########| 1/1 [15:50<00:00, 950.43s/ file]
# Dl Completed...: 100%|##########| 3/3 [15:50<00:00, 280.46s/ url]
#
# Dl Size...: 100%|##########| 328/328 [15:50<00:00,  2.79s/ MiB]
#
#
# Extraction completed...: 100%|##########| 1/1 [15:50<00:00, 950.43s/ file]
# Extraction completed...: 100%|##########| 1/1 [15:50<00:00, 950.43s/ file]
#
# Dl Size...: 100%|##########| 328/328 [15:50<00:00,  2.90s/ MiB]
#
# Dl Completed...: 100%|##########| 3/3 [15:50<00:00, 316.81s/ url]
# I0829 20:31:55.191110 14052 dataset_builder.py:947] Generating split train
#
# 0 examples [00:00, ? examples/s]
# 56 examples [00:00, 555.94 examples/s]
# 161 examples [00:00, 646.44 examples/s]
# 270 examples [00:00, 735.19 examples/s]
# 381 examples [00:00, 816.74 examples/s]
# 461 examples [00:00, 807.48 examples/s]
# 539 examples [00:00, 762.27 examples/s]
# 614 examples [00:00, 745.62 examples/s]
# 688 examples [00:00, 731.24 examples/s]
# 762 examples [00:00, 732.33 examples/s]
# 862 examples [00:01, 794.88 examples/s]
# 970 examples [00:01, 861.74 examples/s]
#
#
#   0%|          | 0/1020 [00:00<?, ? examples/s]I0829 20:31:56.498583 14052 tfrecords_writer.py:230] Done writing C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-train.tfrecord. Shard lengths: [1020]
#
#
# I0829 20:31:56.502604 14052 dataset_builder.py:947] Generating split test
#
# 0 examples [00:00, ? examples/s]
# 103 examples [00:00, 1022.53 examples/s]
# 215 examples [00:00, 1047.78 examples/s]
# 322 examples [00:00, 1052.08 examples/s]
# 430 examples [00:00, 1058.13 examples/s]
# 542 examples [00:00, 1073.60 examples/s]
# 658 examples [00:00, 1095.84 examples/s]
# 771 examples [00:00, 1103.64 examples/s]
# 888 examples [00:00, 1120.28 examples/s]
# 996 examples [00:00, 1105.37 examples/s]
# 1105 examples [00:01, 1095.00 examples/s]
# 1217 examples [00:01, 1100.01 examples/s]
# 1329 examples [00:01, 1100.30 examples/s]
# 1440 examples [00:01, 1100.79 examples/s]
# 1553 examples [00:01, 1107.02 examples/s]
# 1664 examples [00:01, 1092.46 examples/s]
# 1773 examples [00:01, 1086.08 examples/s]
# 1882 examples [00:01, 1070.51 examples/s]
# 1996 examples [00:01, 1088.27 examples/s]
# 2105 examples [00:01, 1070.33 examples/s]
# 2217 examples [00:02, 1082.57 examples/s]
# 2326 examples [00:02, 1048.18 examples/s]
# 2432 examples [00:02, 1040.06 examples/s]
# 2541 examples [00:02, 1052.33 examples/s]
# 2648 examples [00:02, 1055.29 examples/s]
# 2754 examples [00:02, 1032.97 examples/s]
# 2865 examples [00:02, 1052.74 examples/s]
# 2974 examples [00:02, 1061.27 examples/s]
# 3085 examples [00:02, 1073.08 examples/s]
# 3199 examples [00:02, 1090.07 examples/s]
# 3309 examples [00:03, 1087.33 examples/s]
# 3419 examples [00:03, 1088.72 examples/s]
# 3528 examples [00:03, 1083.49 examples/s]
# 3637 examples [00:03, 1083.07 examples/s]
# 3749 examples [00:03, 1091.66 examples/s]
# 3859 examples [00:03, 1066.34 examples/s]
# 3971 examples [00:03, 1079.56 examples/s]
# 4080 examples [00:03, 1073.98 examples/s]
# 4188 examples [00:03, 1057.81 examples/s]
# 4294 examples [00:04, 988.38 examples/s]
# 4394 examples [00:04, 966.79 examples/s]
# 4492 examples [00:04, 960.00 examples/s]
# 4603 examples [00:04, 998.68 examples/s]
# 4715 examples [00:04, 1030.14 examples/s]
# 4825 examples [00:04, 1047.86 examples/s]
# 4932 examples [00:04, 1052.14 examples/s]
# 5039 examples [00:04, 1055.13 examples/s]
# 5145 examples [00:04, 1038.80 examples/s]
# 5250 examples [00:04, 1033.88 examples/s]
# 5358 examples [00:05, 1044.98 examples/s]
# 5471 examples [00:05, 1066.90 examples/s]
# 5583 examples [00:05, 1081.56 examples/s]
# 5692 examples [00:05, 1059.71 examples/s]
# 5800 examples [00:05, 1063.52 examples/s]
# 5908 examples [00:05, 1066.10 examples/s]
# 6019 examples [00:05, 1076.41 examples/s]
# 6127 examples [00:05, 1075.33 examples/s]
#
#
#   0%|          | 0/6149 [00:00<?, ? examples/s]
#  26%|##6       | 1601/6149 [00:00<00:00, 15888.83 examples/s]
#  50%|####9     | 3074/6149 [00:00<00:00, 10389.32 examples/s]
#  77%|#######7  | 4745/6149 [00:00<00:00, 11700.42 examples/s]I0829 20:32:03.219333 14052 tfrecords_writer.py:230] Done writing C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-test.tfrecord. Shard lengths: [3074, 3075]
#
#
# I0829 20:32:03.246210 14052 dataset_builder.py:947] Generating split validation
#
# 0 examples [00:00, ? examples/s]
# 99 examples [00:00, 982.42 examples/s]
# 181 examples [00:00, 925.15 examples/s]
# 280 examples [00:00, 941.63 examples/s]
# 391 examples [00:00, 984.70 examples/s]
# 510 examples [00:00, 1036.37 examples/s]
# 621 examples [00:00, 1055.31 examples/s]
# 729 examples [00:00, 1060.20 examples/s]
# 834 examples [00:00, 1054.80 examples/s]
# 936 examples [00:00, 1041.86 examples/s]
#
#
#   0%|          | 0/1020 [00:00<?, ? examples/s]I0829 20:32:04.542339 14052 tfrecords_writer.py:230] Done writing C:\Users\alexa\tensorflow_datasets\oxford_flowers102\2.1.1.incompleteWCBVR9\oxford_flowers102-validation.tfrecord. Shard lengths: [1020]
#
#
# I0829 20:32:04.547341 14052 dataset_builder.py:401] Skipping computing stats for mode ComputeStatsMode.SKIP.

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
print(dataset_info.splits)

# TODO: Get the number of classes in the dataset from the dataset info.
print('\n', dataset_info.features['label'])
# Out:
# {'test': <tfds.core.SplitInfo num_examples=6149>, 'train': <tfds.core.SplitInfo num_examples=1020>, 'validation': <tfds.core.SplitInfo num_examples=1020>}
#
#  ClassLabel(shape=(), dtype=tf.int64, num_classes=102)

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.    
for image, label in training_set.take(1):
    print(f"Image datatype: {image.dtype}")
    print(f"Image shape: {image.shape}")
# Out:
# Image datatype: <dtype: 'uint8'>
# Image shape: (500, 667, 3)

# %%
# TODO: Plot 1 image from the training set. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
    
# Set the title of the plot to the corresponding image label. 
plt.imshow(image, cmap= plt.cm.binary)
plt.title(label)
plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
    
# Set the title of the plot to the corresponding image label. 
plt.imshow(image, cmap= plt.cm.binary)
plt.title(class_names[str(label)])
plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.
def preprocess_data(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image / 255.0
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_train // 4).map(preprocess_data).batch(batch_size).prefetch(1)
validation_batches = validation_set.cache().shuffle(num_validate // 4).map(preprocess_data).batch(batch_size).prefetch(1)
testing_batches = test_set.cache().map(preprocess_data).batch(batch_size).prefetch(1)

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
feature_extractor = hub.KerasLayer(URL, input_shape = (IMG_SIZE, IMG_SIZE, 3))
feature_extractor.trainable = False

model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Dense(1028,activation ='relu'),
    tf.keras.layers.Dense(102, activation = 'softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 1028)              1316868
# _________________________________________________________________
# dense_1 (Dense)              (None, 102)               104958
# =================================================================
# Total params: 3,679,810
# Trainable params: 1,421,826
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = ['accuracy'])

EPOCHS = 15

history = model.fit(training_batches, epochs = EPOCHS, validation_data = validation_batches)
# Out:
# Epoch 1/15
# 16/16 [==============================] - 24s 1s/step - loss: 3.8895 - accuracy: 0.2127 - val_loss: 2.5119 - val_accuracy: 0.5255
# Epoch 2/15
# 16/16 [==============================] - 23s 1s/step - loss: 1.2293 - accuracy: 0.7971 - val_loss: 1.2968 - val_accuracy: 0.7029
# Epoch 3/15
# 16/16 [==============================] - 24s 2s/step - loss: 0.4021 - accuracy: 0.9294 - val_loss: 1.0136 - val_accuracy: 0.7441
# Epoch 4/15
# 16/16 [==============================] - 26s 2s/step - loss: 0.1762 - accuracy: 0.9775 - val_loss: 0.8588 - val_accuracy: 0.7843
# Epoch 5/15
# 16/16 [==============================] - 26s 2s/step - loss: 0.0661 - accuracy: 1.0000 - val_loss: 0.7815 - val_accuracy: 0.7951
# Epoch 6/15
# 16/16 [==============================] - 26s 2s/step - loss: 0.0357 - accuracy: 0.9990 - val_loss: 0.7420 - val_accuracy: 0.8059
# Epoch 7/15
# 16/16 [==============================] - 24s 1s/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.7206 - val_accuracy: 0.8127
# Epoch 8/15
# 16/16 [==============================] - 25s 2s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.7050 - val_accuracy: 0.8118
# Epoch 9/15
# 16/16 [==============================] - 27s 2s/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.6960 - val_accuracy: 0.8147
# Epoch 10/15
# 16/16 [==============================] - 29s 2s/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.6932 - val_accuracy: 0.8206
# Epoch 11/15
# 16/16 [==============================] - 26s 2s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.6856 - val_accuracy: 0.8108
# Epoch 12/15
# 16/16 [==============================] - 24s 1s/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.6835 - val_accuracy: 0.8176
# Epoch 13/15
# 16/16 [==============================] - 34s 2s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.6781 - val_accuracy: 0.8167
# Epoch 14/15
# 16/16 [==============================] - 31s 2s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.6766 - val_accuracy: 0.8157
# Epoch 15/15
# 16/16 [==============================] - 23s 1s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.6750 - val_accuracy: 0.8157

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
def show_plots(hist, epochs):
    training_accuracy = hist.history['accuracy']
    training_loss = hist.history['loss']

    validation_accuracy = hist.history['val_accuracy']
    validation_loss = hist.history['val_loss']

    epochs_range = range(epochs)

    plt.figure(figsize = (8,4))
    plt.subplot(1,2,1)
    plt.plot(epochs_range, training_accuracy, label = 'Training Accuracy')
    plt.plot(epochs_range, validation_accuracy, label = 'Validation Accuracy')
    plt.legend(loc = 'lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1,2,2)
    plt.plot(epochs_range, training_loss, label = 'Training Loss')
    plt.plot(epochs_range, validation_loss, label = 'Validation Loss')
    plt.legend(loc = 'upper right')
    plt.title('Training and Validation Loss')

    plt.show()
    
show_plots(history, EPOCHS)

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
for image, label in testing_batches.take(1):
    loss, accuracy = model.evaluate(image, label)
    
print(f"Loss in one testing batch: {loss}")
print(f"Accuracy in one testing bathc: {accuracy}")
# Out:
# 2/2 [==============================] - 0s 173ms/step - loss: 0.7850 - accuracy: 0.7969
# Loss in one testing batch: 0.7849615812301636
# Accuracy in one testing bathc: 0.796875

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.
import time
import os
t = time.time()
model_dir = './models'
if not os.path.isdir(model_dir):
    os.mkdir(model_dir)
model_path = f'./models/{str(t)}.h5'
model.save(model_path)

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
print(model_path)
rl_model = tf.keras.models.load_model(model_path, custom_objects={'KerasLayer':hub.KerasLayer})
# Out:
# ./models/1598764446.5732443.h5

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
img_size = 224
def process_image(img):
    img = tf.image.convert_image_dtype(img, dtype = tf.float32)
    img = tf.image.resize(img, (img_size, img_size))
    return img.numpy()

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function
import pandas as pd

def predict(img_path, mdl, top_k):
    img = np.asarray(Image.open(img_path))
    img = process_image(img)
    img = np.expand_dims(img, axis = 0)
    ret = mdl.predict(img)
    df = pd.DataFrame(data = ret[0], index = list(range(len(ret[0]))), columns = ['prob'])
    df = df.sort_values(by = ['prob'], ascending = False)
    df.index.name = 'class'
    df.reset_index(inplace=True)
    cls = df['class'].to_list()
    cls = [x + 1 for x in cls]
    prbs = df['prob'].to_list()
    return prbs[:top_k], cls[:top_k]

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
import random

def plot_img_probs(image_path):
    probs, classes = predict(image_path, model, 5)
    classes = [class_names[str(x)] for x in classes]

    image = np.asarray(Image.open(image_path))
    image = process_image(image)

    fig, (ax1, ax2) = plt.subplots(figsize=(10,3), ncols=2)
    ax1.imshow(image)
    ax1.set_title('Image')
    ax2.barh(classes, probs)
    ax2.set_title('Class Probability')
    fig.tight_layout(pad=1.0)
    
names = ['cautleya_spicata.jpg', 'hard-leaved_pocket_orchid.jpg', 'orange_dahlia.jpg', 'wild_pansy.jpg']
this_name = names[random.randint(0,3)]
img_path = f'./test_images/{this_name}'
plot_img_probs(img_path)
